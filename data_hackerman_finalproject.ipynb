# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.options.display.max_colwidth = None
pd.set_option("display.float_format", lambda x: '%.2f' % x)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
########### Python 3.2 #############
import urllib.request, json

try:
    url = "https://api.tfl.gov.uk/Journey/JourneyResults/SE28%200NH/to/SE8%203BQ?timeIs=Arriving&journeyPreference=LeastInterchange&accessibilityPreference=NoRequirements&walkingSpeed=Slow&cyclePreference=None&bikeProficiency=Easy"

    hdr ={
    # Request headers
    'Cache-Control': 'no-cache',
    }

    req = urllib.request.Request(url, headers=hdr)

    req.get_method = lambda: 'GET'
    response = urllib.request.urlopen(req)
    print(response.getcode())
    print(response.read())
except Exception as e:
    print(e)
####################################
# Out:
# 200
# ...

# %%
#pip install -q requests
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
 url = "https://anapioficeandfire.com/api/books"
 result = requests.get(url)

# %%
result.status_code
# Out:
# 200

# %%
result.json()
# Out:
# [{'url': 'https://anapioficeandfire.com/api/books/1',
#   'name': 'A Game of Thrones',
#   'isbn': '978-0553103540',
#   'authors': ['George R. R. Martin'],
#   'numberOfPages': 694,
#   'publisher': 'Bantam Books',
#   'country': 'United States',
#   'mediaType': 'Hardcover',
#   'released': '1996-08-01T00:00:00',
#   'characters': ['https://anapioficeandfire.com/api/characters/2',
#    'https://anapioficeandfire.com/api/characters/12',
#    'https://anapioficeandfire.com/api/characters/13',
#    'https://anapioficeandfire.com/api/characters/16',
#    'https://anapioficeandfire.com/api/characters/20',
#    'https://anapioficeandfire.com/api/characters/27',
#    'https://anapioficeandfire.com/api/characters/31',
#    'https://anapioficeandfire.com/api/characters/38',
#    'https://anapioficeandfire.com/api/characters/39',
#    'https://anapioficeandfire.com/api/characters/40',
#    'https://anapioficeandfire.com/api/characters/41',
# ...

# %% [markdown]
# # What index corresponds to the house "House Breakstone"?

# %%
url = "https://anapioficeandfire.com/api/houses"
result = requests.get(url)

# %%
result.status_code
# Out:
# 200

# %%
result.json()
# Out:
# [{'url': 'https://anapioficeandfire.com/api/houses/1',
#   'name': 'House Algood',
#   'region': 'The Westerlands',
#   'coatOfArms': 'A golden wreath, on a blue field with a gold border(Azure, a garland of laurel within a bordure or)',
#   'words': '',
#   'titles': [''],
#   'seats': [''],
#   'currentLord': '',
#   'heir': '',
#   'overlord': 'https://anapioficeandfire.com/api/houses/229',
#   'founded': '',
#   'founder': '',
#   'diedOut': '',
#   'ancestralWeapons': [''],
#   'cadetBranches': [],
#   'swornMembers': []},
#  {'url': 'https://anapioficeandfire.com/api/houses/2',
#   'name': 'House Allyrion of Godsgrace',
#   'region': 'Dorne',
#   'coatOfArms': 'Gyronny Gules and Sable, a hand couped Or',
#   'words': 'No Foe May Pass',
#   'titles': [''],
#   'seats': ['Godsgrace'],
#   'currentLord': 'https://anapioficeandfire.com/api/characters/298',
#   'heir': 'https://anapioficeandfire.com/api/characters/1922',
# ...

# %%
result_data = result.json()

# %%
type(result_data)
# Out:
# list

# %%
len(result_data)
# Out:
# 10

# %%
pd.DataFrame(result_data)
# Out:
#                                            url                         name  \
# 0   https://anapioficeandfire.com/api/houses/1                 House Algood
# 1   https://anapioficeandfire.com/api/houses/2  House Allyrion of Godsgrace
# 2   https://anapioficeandfire.com/api/houses/3                  House Amber
# 3   https://anapioficeandfire.com/api/houses/4                House Ambrose
# 4   https://anapioficeandfire.com/api/houses/5   House Appleton of Appleton
# 5   https://anapioficeandfire.com/api/houses/6      House Arryn of Gulltown
# 6   https://anapioficeandfire.com/api/houses/7     House Arryn of the Eyrie
# 7   https://anapioficeandfire.com/api/houses/8     House Ashford of Ashford
# 8   https://anapioficeandfire.com/api/houses/9                House Ashwood
# 9  https://anapioficeandfire.com/api/houses/10   House Baelish of Harrenhal
#
#             region  \
# 0  The Westerlands
# 1            Dorne
# 2        The North
# 3        The Reach
# 4        The Reach
# ...

# %%
game_data = pd.DataFrame(result_data)

# %%
game_data["name"]
# Out:
# 0                   House Algood
# 1    House Allyrion of Godsgrace
# 2                    House Amber
# 3                  House Ambrose
# 4     House Appleton of Appleton
# 5        House Arryn of Gulltown
# 6       House Arryn of the Eyrie
# 7       House Ashford of Ashford
# 8                  House Ashwood
# 9     House Baelish of Harrenhal
# Name: name, dtype: object

# %%
game_data["overlord"]
# Out:
# 0    https://anapioficeandfire.com/api/houses/229
# 1    https://anapioficeandfire.com/api/houses/285
# 2
# 3    https://anapioficeandfire.com/api/houses/398
# 4    https://anapioficeandfire.com/api/houses/398
# 5      https://anapioficeandfire.com/api/houses/7
# 6     https://anapioficeandfire.com/api/houses/16
# 7    https://anapioficeandfire.com/api/houses/398
# 8     https://anapioficeandfire.com/api/houses/34
# 9     https://anapioficeandfire.com/api/houses/16
# Name: overlord, dtype: object

# %%
url = "https://anapioficeandfire.com/api/houses/229"

# %%
result = requests.get(url)

# %%
result.status_code
# Out:
# 200

# %%
result.json()
# Out:
# {'url': 'https://anapioficeandfire.com/api/houses/229',
#  'name': 'House Lannister of Casterly Rock',
#  'region': 'The Westerlands',
#  'coatOfArms': 'A gold lion, on a crimson field(Gules, a lion or)',
#  'words': 'Hear Me Roar!',
#  'titles': ['King of the Rock (formerly) Lord of Casterly Rock',
#   'Shield of Lannisport',
#   'Warden of the West'],
#  'seats': ['Casterly Rock'],
#  'currentLord': 'https://anapioficeandfire.com/api/characters/238',
#  'heir': '',
#  'overlord': 'https://anapioficeandfire.com/api/houses/16',
#  'founded': 'Age of Heroes',
#  'founder': 'https://anapioficeandfire.com/api/characters/615',
#  'diedOut': '',
#  'ancestralWeapons': ['Brightroar'],
#  'cadetBranches': ['https://anapioficeandfire.com/api/houses/228',
#   'https://anapioficeandfire.com/api/houses/230',
#   'https://anapioficeandfire.com/api/houses/231',
#   'https://anapioficeandfire.com/api/houses/232',
#   'https://anapioficeandfire.com/api/houses/233'],
# ...

# %%
result_data = result.json()

# %%
len(result_data)
# Out:
# 16

# %%
response = requests.get("https://anapioficeandfire.com/api/houses/229")
response.text
# Out:
# '{"url":"https://anapioficeandfire.com/api/houses/229","name":"House Lannister of Casterly Rock","region":"The Westerlands","coatOfArms":"A gold lion, on a crimson field(Gules, a lion or)","words":"Hear Me Roar!","titles":["King of the Rock (formerly) Lord of Casterly Rock","Shield of Lannisport","Warden of the West"],"seats":["Casterly Rock"],"currentLord":"https://anapioficeandfire.com/api/characters/238","heir":"","overlord":"https://anapioficeandfire.com/api/houses/16","founded":"Age of Heroes","founder":"https://anapioficeandfire.com/api/characters/615","diedOut":"","ancestralWeapons":["Brightroar"],"cadetBranches":["https://anapioficeandfire.com/api/houses/228","https://anapioficeandfire.com/api/houses/230","https://anapioficeandfire.com/api/houses/231","https://anapioficeandfire.com/api/houses/232","https://anapioficeandfire.com/api/houses/233"],"swornMembers":["https://anapioficeandfire.com/api/characters/27","https://anapioficeandfire.com/api/characters/101","https://anapiof
# ...

# %% [markdown]
# # How many males, females and unknown genders are there in the first 40 characters?
# Note, index 0 does not correspond to a character,
# so full range is 1 - 40 both ends inclusive.

# %%
response = requests.get("https://www.anapioficeandfire.com/api/characters")

# %%
 result = requests.get(url)

# %%
result.status_code
# Out:
# 200

# %%
result.json()
# Out:
# [{'url': 'https://anapioficeandfire.com/api/houses/1',
#   'name': 'House Algood',
#   'region': 'The Westerlands',
#   'coatOfArms': 'A golden wreath, on a blue field with a gold border(Azure, a garland of laurel within a bordure or)',
#   'words': '',
#   'titles': [''],
#   'seats': [''],
#   'currentLord': '',
#   'heir': '',
#   'overlord': 'https://anapioficeandfire.com/api/houses/229',
#   'founded': '',
#   'founder': '',
#   'diedOut': '',
#   'ancestralWeapons': [''],
#   'cadetBranches': [],
#   'swornMembers': []},
#  {'url': 'https://anapioficeandfire.com/api/houses/2',
#   'name': 'House Allyrion of Godsgrace',
#   'region': 'Dorne',
#   'coatOfArms': 'Gyronny Gules and Sable, a hand couped Or',
#   'words': 'No Foe May Pass',
#   'titles': [''],
#   'seats': ['Godsgrace'],
#   'currentLord': 'https://anapioficeandfire.com/api/characters/298',
#   'heir': 'https://anapioficeandfire.com/api/characters/1922',
# ...

# %%
len(result_data)
# Out:
# 10

# %%
pd.DataFrame(result_data)
# Out:
#                                            url                         name  \
# 0   https://anapioficeandfire.com/api/houses/1                 House Algood
# 1   https://anapioficeandfire.com/api/houses/2  House Allyrion of Godsgrace
# 2   https://anapioficeandfire.com/api/houses/3                  House Amber
# 3   https://anapioficeandfire.com/api/houses/4                House Ambrose
# 4   https://anapioficeandfire.com/api/houses/5   House Appleton of Appleton
# 5   https://anapioficeandfire.com/api/houses/6      House Arryn of Gulltown
# 6   https://anapioficeandfire.com/api/houses/7     House Arryn of the Eyrie
# 7   https://anapioficeandfire.com/api/houses/8     House Ashford of Ashford
# 8   https://anapioficeandfire.com/api/houses/9                House Ashwood
# 9  https://anapioficeandfire.com/api/houses/10   House Baelish of Harrenhal
#
#             region  \
# 0  The Westerlands
# 1            Dorne
# 2        The North
# 3        The Reach
# 4        The Reach
# ...

# %%
result.json()
# Out:
# [{'url': 'https://anapioficeandfire.com/api/houses/1',
#   'name': 'House Algood',
#   'region': 'The Westerlands',
#   'coatOfArms': 'A golden wreath, on a blue field with a gold border(Azure, a garland of laurel within a bordure or)',
#   'words': '',
#   'titles': [''],
#   'seats': [''],
#   'currentLord': '',
#   'heir': '',
#   'overlord': 'https://anapioficeandfire.com/api/houses/229',
#   'founded': '',
#   'founder': '',
#   'diedOut': '',
#   'ancestralWeapons': [''],
#   'cadetBranches': [],
#   'swornMembers': []},
#  {'url': 'https://anapioficeandfire.com/api/houses/2',
#   'name': 'House Allyrion of Godsgrace',
#   'region': 'Dorne',
#   'coatOfArms': 'Gyronny Gules and Sable, a hand couped Or',
#   'words': 'No Foe May Pass',
#   'titles': [''],
#   'seats': ['Godsgrace'],
#   'currentLord': 'https://anapioficeandfire.com/api/characters/298',
#   'heir': 'https://anapioficeandfire.com/api/characters/1922',
# ...

# %%
response = requests.get("https://www.anapioficeandfire.com/api/characters")
response.text
# Out:
# '[{"url":"https://www.anapioficeandfire.com/api/characters/1","name":"","gender":"Female","culture":"Braavosi","born":"","died":"","titles":[""],"aliases":["The Daughter of the Dusk"],"father":"","mother":"","spouse":"","allegiances":[],"books":["https://www.anapioficeandfire.com/api/books/5"],"povBooks":[],"tvSeries":[""],"playedBy":[""]},{"url":"https://www.anapioficeandfire.com/api/characters/2","name":"Walder","gender":"Male","culture":"","born":"","died":"","titles":[""],"aliases":["Hodor"],"father":"","mother":"","spouse":"","allegiances":["https://www.anapioficeandfire.com/api/houses/362"],"books":["https://www.anapioficeandfire.com/api/books/1","https://www.anapioficeandfire.com/api/books/2","https://www.anapioficeandfire.com/api/books/3","https://www.anapioficeandfire.com/api/books/5","https://www.anapioficeandfire.com/api/books/8"],"povBooks":[],"tvSeries":["Season 1","Season 2","Season 3","Season 4","Season 6"],"playedBy":["Kristian Nairn"]},{"url":"https://www.anapioficea
# ...

# %%
character_data
# Out:
#                                            url                         name  \
# 0   https://anapioficeandfire.com/api/houses/1                 House Algood
# 1   https://anapioficeandfire.com/api/houses/2  House Allyrion of Godsgrace
# 2   https://anapioficeandfire.com/api/houses/3                  House Amber
# 3   https://anapioficeandfire.com/api/houses/4                House Ambrose
# 4   https://anapioficeandfire.com/api/houses/5   House Appleton of Appleton
# 5   https://anapioficeandfire.com/api/houses/6      House Arryn of Gulltown
# 6   https://anapioficeandfire.com/api/houses/7     House Arryn of the Eyrie
# 7   https://anapioficeandfire.com/api/houses/8     House Ashford of Ashford
# 8   https://anapioficeandfire.com/api/houses/9                House Ashwood
# 9  https://anapioficeandfire.com/api/houses/10   House Baelish of Harrenhal
#
#             region  \
# 0  The Westerlands
# 1            Dorne
# 2        The North
# 3        The Reach
# 4        The Reach
# ...

# %%
test_output = requests.get("https://randomuser.me/api/?gender=female")

# %%
test_output.json()
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'Andrea', 'last': 'Marinković'},
#    'location': {'street': {'number': 7811, 'name': 'Stevana Sremca'},
#     'city': 'Čačak',
#     'state': 'Kolubara',
#     'country': 'Serbia',
#     'postcode': 42862,
#     'coordinates': {'latitude': '64.0958', 'longitude': '-161.5201'},
#     'timezone': {'offset': '+7:00', 'description': 'Bangkok, Hanoi, Jakarta'}},
#    'email': 'andrea.marinkovic@example.com',
#    'login': {'uuid': '64dcd225-3ef5-4992-9738-ebeda0a27642',
#     'username': 'brownleopard907',
#     'password': 'jiao',
#     'salt': 'o60wMJie',
#     'md5': '6dd191264e5d1b6de80cec482b535d74',
#     'sha1': '62ddddf4ac911d765133ef799be4ac0e220ed3ba',
#     'sha256': '97bfbb2fa4b5474f74866f2842462b3e6bdb1d05eb4906c7cbc5707e7a25eeb9'},
#    'dob': {'date': '1986-08-20T18:08:36.571Z', 'age': 36},
#    'registered': {'date': '2020-10-03T15:37:06.632Z', 'age': 2},
#    'phone': '020-6144-216',
# ...

# %%
test_output = requests.get("https://randomuser.me/api/?gender=male")

# %%
test_output.json()
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Lincoln', 'last': 'Thomas'},
#    'location': {'street': {'number': 6121, 'name': 'Omahu Road'},
#     'city': 'Lower Hutt',
#     'state': 'Taranaki',
#     'country': 'New Zealand',
#     'postcode': 64130,
#     'coordinates': {'latitude': '55.5955', 'longitude': '55.7563'},
#     'timezone': {'offset': '-8:00',
#      'description': 'Pacific Time (US & Canada)'}},
#    'email': 'lincoln.thomas@example.com',
#    'login': {'uuid': 'b2996b9e-4d25-4b5b-8c95-6220e6a6849c',
#     'username': 'silverlion420',
#     'password': '1981',
#     'salt': '5rYkuRxR',
#     'md5': '10c6157b19f3a1f81863eaff682f3bbb',
#     'sha1': 'af18c68d9bb9096cef5228287b6abb41bd49ab37',
#     'sha256': '8c53d9c08d32c60ca80b6e167e46ca52fb50fc91bd9bd3373e6563013a20a700'},
#    'dob': {'date': '1967-01-19T04:55:57.009Z', 'age': 56},
#    'registered': {'date': '2005-02-10T12:58:19.913Z', 'age': 18},
#    'phone': '(094)-645-3579',
# ...

# %%
test_output = requests.get("https://randomuser.me/api/?gender=female")

# %%
test_output.json()
# Out:
# {'results': [{'gender': 'female',
#    'name': {'title': 'Miss', 'first': 'الینا', 'last': 'سلطانی نژاد'},
#    'location': {'street': {'number': 245, 'name': 'حقانی'},
#     'city': 'اردبیل',
#     'state': 'قم',
#     'country': 'Iran',
#     'postcode': 38009,
#     'coordinates': {'latitude': '13.4557', 'longitude': '-110.7145'},
#     'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}},
#    'email': 'lyn.sltnynjd@example.com',
#    'login': {'uuid': '51603194-2ac4-404d-a9af-6d688f242585',
#     'username': 'redzebra439',
#     'password': 'magnus',
#     'salt': 'lOYpar25',
#     'md5': 'f6047ed32459c5c738d0a99f7370658c',
#     'sha1': '1ea069fe57b98e2a36cbb45e812ea37694ad35f7',
#     'sha256': 'c19ca3a91f60e61bdf31046125180eee15171ea9e5d5aab3135a6e0de5bdb656'},
#    'dob': {'date': '1994-04-22T04:55:15.105Z', 'age': 28},
#    'registered': {'date': '2010-02-25T01:02:44.512Z', 'age': 13},
#    'phone': '059-12135339',
#    'cell': '0977-993-2126',
# ...

# %%
pd.DataFrame(test_output)
# Out:
#                                                                                                                                                                                                                                0
# 0  b'{"results":[{"gender":"female","name":{"title":"Miss","first":"\xd8\xa7\xd9\x84\xdb\x8c\xd9\x86\xd8\xa7","last":"\xd8\xb3\xd9\x84\xd8\xb7\xd8\xa7\xd9\x86\xdb\x8c \xd9\x86\xda\x98\xd8\xa7\xd8\xaf"},"location":{"street":'
# 1              b'{"number":245,"name":"\xd8\xad\xd9\x82\xd8\xa7\xd9\x86\xdb\x8c"},"city":"\xd8\xa7\xd8\xb1\xd8\xaf\xd8\xa8\xdb\x8c\xd9\x84","state":"\xd9\x82\xd9\x85","country":"Iran","postcode":38009,"coordinates":{"latitu'
# 2                                                                                            b'de":"13.4557","longitude":"-110.7145"},"timezone":{"offset":"-2:00","description":"Mid-Atlantic"}},"email":"lyn.sltnynjd@example'
# ...

# %% [markdown]
# # How many books can be accessed from this API?

# %%
url = "https://www.anapioficeandfire.com/api/books"

# %%
result = requests.get(url)

# %%
result.json()
# Out:
# [{'url': 'https://www.anapioficeandfire.com/api/books/1',
#   'name': 'A Game of Thrones',
#   'isbn': '978-0553103540',
#   'authors': ['George R. R. Martin'],
#   'numberOfPages': 694,
#   'publisher': 'Bantam Books',
#   'country': 'United States',
#   'mediaType': 'Hardcover',
#   'released': '1996-08-01T00:00:00',
#   'characters': ['https://www.anapioficeandfire.com/api/characters/2',
#    'https://www.anapioficeandfire.com/api/characters/12',
#    'https://www.anapioficeandfire.com/api/characters/13',
#    'https://www.anapioficeandfire.com/api/characters/16',
#    'https://www.anapioficeandfire.com/api/characters/20',
#    'https://www.anapioficeandfire.com/api/characters/27',
#    'https://www.anapioficeandfire.com/api/characters/31',
#    'https://www.anapioficeandfire.com/api/characters/38',
#    'https://www.anapioficeandfire.com/api/characters/39',
#    'https://www.anapioficeandfire.com/api/characters/40',
#    'https://www.anapioficeandfire.com/api/characters/41',
# ...

# %% [markdown]
# #  How many books does the character 'High Septon' appear in? (ignoring 'povcharacters')
